# %% [markdown]
# ## Small data exploration

# %%
from pathlib import Path
import pandas as pd
data_dir = Path("data/")
data = pd.read_csv(data_dir / "lyrics.csv")

# %%
print(f"shape of data: {data.shape}")
# Out:
# shape of data: (362237, 6)

# %%
artists = list(dict.fromkeys(list(data['artist'])))
years = list(dict.fromkeys(list(data['year'])))
genres = list(dict.fromkeys(list(data['genre'])))
print("Number of different artists:", len(artists))
print("Number of different years:",len(years))
print("Number of different genres:", len(genres))
# Out:
# Number of different artists: 18231
# Number of different years: 52
# Number of different genres: 12

# %%
print(dict(data['artist'].value_counts()))
# Out:
# {'dolly-parton': 755, 'american-idol': 700, 'elton-john': 680, 'b-b-king': 667, 'chris-brown': 655, 'eddy-arnold': 628, 'barbra-streisand': 624, 'ella-fitzgerald': 623, 'bob-dylan': 614, 'bee-gees': 599, 'david-bowie': 599, 'dean-martin': 593, 'eminem': 589, 'celine-dion': 551, 'frank-zappa': 550, 'bruce-springsteen': 534, 'elvis-costello': 534, 'eric-clapton': 522, 'beach-boys': 520, 'bill-anderson': 473, 'chicago': 461, 'frank-sinatra': 435, 'beatles': 429, 'chamillionaire': 428, '50-cent': 425, 'chumbawamba': 423, 'britney-spears': 422, 'diana-ross': 420, 'emmylou-harris': 419, 'cedarmont-kids': 417, 'bon-jovi': 407, 'fall': 404, 'armin-van-buuren': 397, '2pac': 386, 'drake': 386, 'disney': 381, 'game': 379, 'die-toten-hosen': 379, 'barry-manilow': 378, 'e-40': 374, 'elvis-presley': 373, 'babyface': 368, 'fleetwood-mac': 365, 'buck-owens': 357, 'conway-twitty': 355, 'aretha-franklin': 354, 'electric-light-orchestra': 351, 'cliff-richard': 346, 'ernest-tubb': 335, 'bill-evans': 333
# ...

# %%
print(dict(data['year'].value_counts()))
# Out:
# {2006: 76590, 2007: 63677, 2016: 37409, 2015: 28766, 2014: 28250, 2008: 21497, 2013: 17331, 2012: 15789, 2010: 12106, 2011: 12067, 2009: 12029, 2005: 5719, 2004: 3698, 2003: 2187, 2002: 2158, 2000: 1722, 1999: 1586, 2001: 1570, 1990: 1362, 1997: 1304, 1998: 1285, 1996: 1236, 1995: 1160, 1994: 968, 1993: 918, 1992: 907, 1991: 559, 1977: 552, 1971: 541, 1973: 520, 1989: 511, 1972: 509, 1982: 498, 1970: 429, 1979: 420, 1981: 414, 1974: 410, 1978: 407, 1980: 401, 1988: 388, 1986: 365, 1975: 364, 1983: 359, 1976: 344, 1985: 333, 1987: 307, 1984: 298, 2038: 10, 112: 4, 702: 1, 1968: 1, 67: 1}

# %%
print(dict(data['genre'].value_counts()))
# Out:
# {'Rock': 131377, 'Pop': 49444, 'Hip-Hop': 33965, 'Not Available': 29814, 'Metal': 28408, 'Other': 23683, 'Country': 17286, 'Jazz': 17147, 'Electronic': 16205, 'R&B': 5935, 'Indie': 5732, 'Folk': 3241}
